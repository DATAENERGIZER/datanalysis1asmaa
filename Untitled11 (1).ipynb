# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"/content/file (1).xlsx")

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10453  2022-11-07 00:00:00           Beverages
# 3           NaN      10454  2022-11-07 00:00:00       Sides & Other
# 4           NaN      10455  2022-11-08 00:00:00             Burgers
# ..          ...        ...                  ...                 ...
# 250         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 251         NaN      10710  2022-12-29 00:00:00             Burgers
# 252         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 253         NaN      10712  2022-12-29 00:00:00               Fries
# 254         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7     Unnamed: 8  \
# 0        Price    Quantity  Purchase Type  Payment Method        Manager
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    object
#  2   Unnamed: 2  255 non-null    object
#  3   Unnamed: 3  255 non-null    object
#  4   Unnamed: 4  255 non-null    object
#  5   Unnamed: 5  255 non-null    object
#  6   Unnamed: 6  255 non-null    object
#  7   Unnamed: 7  255 non-null    object
#  8   Unnamed: 8  255 non-null    object
#  9   Unnamed: 9  255 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.1+ KB

# %%
data.drop (columns="Unnamed: 0",inplace=True)

# %%
data.head()
# Out:
#   Unnamed: 1           Unnamed: 2     Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0   Order ID                 Date        Product      Price    Quantity
# 1      10452  2022-11-07 00:00:00          Fries       3.49  573.065903
# 2      10453  2022-11-07 00:00:00      Beverages       2.95  745.762712
# 3      10454  2022-11-07 00:00:00  Sides & Other       4.99  200.400802
# 4      10455  2022-11-08 00:00:00        Burgers      12.99  569.668976
#
#       Unnamed: 6      Unnamed: 7     Unnamed: 8 Unnamed: 9
# 0  Purchase Type  Payment Method        Manager       City
# 1        Online        Gift Card    Tom Jackson     London
# 2        Online        Gift Card    Pablo Perez     Madrid
# 3      In-store        Gift Card     Joao Silva     Lisbon
# 4      In-store      Credit Card  Walter Muller     Berlin

# %% [markdown]
# changing the columns names

# %%
data.columns= data.loc[0]
data.head()
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 0  Order ID                 Date        Product  Price    Quantity
# 1     10452  2022-11-07 00:00:00          Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00      Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00  Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00        Burgers  12.99  569.668976
#
# 0  Purchase Type  Payment Method        Manager    City
# 0  Purchase Type  Payment Method        Manager    City
# 1        Online        Gift Card    Tom Jackson  London
# 2        Online        Gift Card    Pablo Perez  Madrid
# 3      In-store        Gift Card     Joao Silva  Lisbon
# 4      In-store      Credit Card  Walter Muller  Berlin

# %%
data.Manager
# Out:
# 0            Manager
# 1        Tom Jackson
# 2        Pablo Perez
# 3         Joao Silva
# 4      Walter Muller
#            ...
# 250    Walter Muller
# 251    Walter Muller
# 252    Walter Muller
# 253    Walter Muller
# 254    Walter Muller
# Name: Manager, Length: 255, dtype: object

# %%
data.Manager.unique()
# Out:
# array(['Manager', 'Tom Jackson', 'Pablo Perez', 'Joao Silva',
#        'Walter Muller', 'Remy Monet'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 7

# %%
data["Manager"].str.strip().str.replace("r\s," , "  ",regex= True)
# Out:
# 0            Manager
# 1        Tom Jackson
# 2        Pablo Perez
# 3         Joao Silva
# 4      Walter Muller
#            ...
# 250    Walter Muller
# 251    Walter Muller
# 252    Walter Muller
# 253    Walter Muller
# 254    Walter Muller
# Name: Manager, Length: 255, dtype: object

# %%
data.head(20)
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 0   Order ID                 Date             Product  Price    Quantity
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 6      10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 7      10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 8      10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 9      10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 10     10462  2022-11-09 00:00:00               Fries   3.49  573.065903
# 11     10463  2022-11-09 00:00:00           Beverages   2.95  677.966102
# ...

# %%
data["Manager"].unique()
# Out:
# array(['Manager', 'Tom Jackson', 'Pablo Perez', 'Joao Silva',
#        'Walter Muller', 'Remy Monet'], dtype=object)

# %%
data['Manager'].str.strip()
# Out:
# 0            Manager
# 1        Tom Jackson
# 2        Pablo Perez
# 3         Joao Silva
# 4      Walter Muller
#            ...
# 250    Walter Muller
# 251    Walter Muller
# 252    Walter Muller
# 253    Walter Muller
# 254    Walter Muller
# Name: Manager, Length: 255, dtype: object

# %%
data['Manager'].drop_duplicates()
# Out:
# 0          Manager
# 1      Tom Jackson
# 2      Pablo Perez
# 3       Joao Silva
# 4    Walter Muller
# 6       Remy Monet
# Name: Manager, dtype: object

# %%
data.head(20)
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 0   Order ID                 Date             Product  Price    Quantity
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 6      10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 7      10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 8      10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 9      10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 10     10462  2022-11-09 00:00:00               Fries   3.49  573.065903
# 11     10463  2022-11-09 00:00:00           Beverages   2.95  677.966102
# ...

# %%
data['Manager']=data['Manager'].str.strip().str.replace("r\s," , "  ",regex= True)

# %%
data.head(20)
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 0   Order ID                 Date             Product  Price    Quantity
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 6      10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 7      10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 8      10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 9      10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 10     10462  2022-11-09 00:00:00               Fries   3.49  573.065903
# 11     10463  2022-11-09 00:00:00           Beverages   2.95  677.966102
# ...

# %%
data['Manager'].nunique()
# Out:
# 6

# %%
data['Manager'].drop_duplicates()
# Out:
# 0          Manager
# 1      Tom Jackson
# 2      Pablo Perez
# 3       Joao Silva
# 4    Walter Muller
# 6       Remy Monet
# Name: Manager, dtype: object

# %% [markdown]
# Removing Duplicate Values

# %%
data.describe()
# Out:
# 0       Order ID                 Date  Product   Price    Quantity  \
# count        255                  255      255  255.00  255.000000
# unique       255                   54        6    8.00   30.000000
# top     Order ID  2022-11-11 00:00:00  Burgers   12.99  200.400802
# freq           1                    5       52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            255            255          255     255
# unique             4              4            6       6
# top          Online     Credit Card  Tom Jackson  London
# freq             107            120           75      75

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# Length: 255, dtype: bool

# %%
data.drop_duplicates(inplace=True)

# %%
data.drop(0,inplace=True)

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# ..       ...                  ...                 ...    ...         ...
# 250    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 251    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 252    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 253    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 254    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method           Manager    City
# ...

# %%
data.describe()
# Out:
# /tmp/ipython-input-50-3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3           12       5
# top          Online     Credit Card  Tom Jackson  London
# ...

# %%
data['Order ID'].duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# Name: Order ID, Length: 254, dtype: bool

# %%
data[data['Order ID']==10483]
# Out:
# 0  Order ID                 Date    Product Price    Quantity Purchase Type  \
# 61    10483  2022-11-13 00:00:00  Beverages  2.95  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 61    Credit Card  Joao Silva  Lisbon

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %% [markdown]
# Converting The Data Type

# %%
data.Quantity=data.Quantity.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 18.0+ KB

# %%
data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar');

# %% [markdown]
# Most Selling Produst?

# %% [markdown]
# By Quantity

# %%
data.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Beverages             34983.050847
# Burgers               29022.324865
# Chicken Sandwiches    11135.678392
# Fries                 32034.383954
# Sides & Other          9819.639279
# Name: Quantity, dtype: float64

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34983.050847
# Fries                 32034.383954
# Burgers               29022.324865
# Chicken Sandwiches    11135.678392
# Sides & Other          9819.639279
# Name: Quantity, dtype: float64

# %%
most_Quantity=data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)  # using groupby on 2 columns and sorting the summed values.
most_Quantity
# Out:
# Product
# Beverages             34983.050847
# Fries                 32034.383954
# Burgers               29022.324865
# Chicken Sandwiches    11135.678392
# Sides & Other          9819.639279
# Name: Quantity, dtype: float64

# %%
most_Quantity=most_Quantity.reset_index()   ## turn most_quantity into a dataframe
most_Quantity
# Out:
#               Product      Quantity
# 0           Beverages  34983.050847
# 1               Fries  32034.383954
# 2             Burgers  29022.324865
# 3  Chicken Sandwiches  11135.678392
# 4       Sides & Other   9819.639279

# %%
plt.figure(figsize=(9,4))
plt.bar(most_Quantity['Product'],most_Quantity['Quantity'],color = ['red','green','blue','purple','black'] ,width = 0.4);
plt.title('Most Selling Product');
plt.xlabel('Product');
plt.ylabel('Quantity');

# %%
data['Date'].fillna(data['Date'].mode()[0])
# Out:
# /tmp/ipython-input-89-624174975.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Date'].fillna(data['Date'].mode()[0])
# 1     2022-11-07
# 2     2022-11-07
# 3     2022-11-07
# 4     2022-11-08
# 5     2022-11-08
#          ...
# 250   2022-12-28
# 251   2022-12-29
# 252   2022-12-29
# 253   2022-12-29
# 254   2022-12-29
# Name: Date, Length: 254, dtype: datetime64[ns]

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5      10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# ..       ...                  ...                 ...    ...         ...
# 250    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 251    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 252    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 253    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 254    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method           Manager    City
# ...

# %%
data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data['Revenue']=data['Quantity']*data['Price']
data['Revenue'] = pd.to_numeric(data['Revenue'])

# %% [markdown]
# Which City Has Maximum Revenue?

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    241713.694547
# London         211200.0
# Madrid         136200.0
# Berlin         100600.0
# Paris           79800.0
# Name: Revenue, dtype: object

# %%
data.Date.dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   Revenue         254 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.0+ KB

# %%
data['Manager'].unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %% [markdown]
# who is the manger that has maximum revenue?

# %%
data.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       241713.694547
# Tom Jackson           211200.0
# Pablo Perez           136200.0
# Walter Muller         100600.0
# Remy Monet             79800.0
# Name: Revenue, dtype: object

# %%
data.plot('Date','Revenue' , color='red' ,linewidth=2 ,figsize=(9,4));
plt.title('Date wise Revenue')
plt.xlabel('Date')
plt.ylabel('Revenue')
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# Average Revenue

# %%
data['Revenue'].mean()
# Out:
# np.float64(3029.5814745954126)

# %% [markdown]
# Average Revenue for November and December?

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   Revenue         254 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 20.0+ KB

# %%
data['Month'] = data['Date'].dt.month
data.head(4)
# Out:
# 0 Order ID       Date        Product  Price    Quantity Purchase Type  \
# 1    10452 2022-11-07          Fries   3.49  573.065903       Online
# 2    10453 2022-11-07      Beverages   2.95  745.762712       Online
# 3    10454 2022-11-07  Sides & Other   4.99  200.400802     In-store
# 4    10455 2022-11-08        Burgers  12.99  569.668976     In-store
#
# 0 Payment Method        Manager    City Revenue  Month
# 1      Gift Card    Tom Jackson  London  2000.0     11
# 2      Gift Card    Pablo Perez  Madrid  2200.0     11
# 3      Gift Card     Joao Silva  Lisbon  1000.0     11
# 4    Credit Card  Walter Muller  Berlin  7400.0     11

# %%
n11=data[data['Month']==11]
n11
# Out:
# 0   Order ID       Date             Product  Price    Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries   3.49  573.065903       Online
# 2      10453 2022-11-07           Beverages   2.95  745.762712       Online
# 3      10454 2022-11-07       Sides & Other   4.99  200.400802     In-store
# 4      10455 2022-11-08             Burgers  12.99  569.668976     In-store
# 5      10456 2022-11-08  Chicken Sandwiches   9.95  201.005025     In-store
# ..       ...        ...                 ...    ...         ...           ...
# 109    10568 2022-11-30           Beverages   2.95  677.966102       Online
# 110    10569 2022-11-30       Sides & Other   4.99  200.400802       Online
# 128    10537 2022-11-24               Fries   3.49  630.372493   Drive-thru
# 129    10538 2022-11-24           Beverages   2.95  745.762712   Drive-thru
# 130    10539 2022-11-24       Sides & Other   4.99  200.400802   Drive-thru
#
# ...

# %%
n11.Revenue.mean()
# Out:
# np.float64(2939.0592437808386)

# %%
n12=data[data['Month']==12]
n12
# Out:
# 0   Order ID       Date             Product  Price    Quantity Purchase Type  \
# 111    10570 2022-12-01             Burgers  12.99  492.686682       Online
# 112    10571 2022-12-01  Chicken Sandwiches   9.95  201.005025       Online
# 113    10572 2022-12-01               Fries   3.49  573.065903       Online
# 114    10573 2022-12-01           Beverages   2.95  677.966102       Online
# 115    10574 2022-12-01       Sides & Other   4.99  200.400802       Online
# ..       ...        ...                 ...    ...         ...           ...
# 250    10709 2022-12-28       Sides & Other   4.99  200.400802   Drive-thru
# 251    10710 2022-12-29             Burgers  12.99  754.426482   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches   9.95  281.407035   Drive-thru
# 253    10712 2022-12-29               Fries   3.49  630.372493   Drive-thru
# 254    10713 2022-12-29           Beverages   2.95  677.966102   Drive-thru
#
# ...

# %%
n12.Revenue.mean()
# Out:
# np.float64(3102.127659574468)

# %% [markdown]
# what is the STD Of Revenue and Quantity?

# %%
data['Quantity'].std()
# Out:
# 214.88955129185305

# %%
data['Revenue'].std()
# Out:
# np.float64(2420.1241927718042)

# %% [markdown]
# the variance of revenue and quantity?

# %%
data['Quantity'].var()
# Out:
# 46177.51925441394

# %%
data['Revenue'].var()
# Out:
# np.float64(5857001.108439377)

# %% [markdown]
# Rvenue for November and December?

# %%
n11['Revenue'].sum()
# Out:
# 332113.69454723474

# %%
n12['Revenue'].sum()
# Out:
# 437400.0

# %% [markdown]
# Average Quantity&Revenue for each Product?

# %%
data.groupby('Product')[['Quantity','Revenue']].agg({'Quantity':'mean', 'Revenue':'mean'})
# Out:
# 0                     Quantity      Revenue
# Product
# Beverages           699.661017  2064.000000
# Burgers             558.121632  7250.000000
# Chicken Sandwiches  214.147661  2204.599923
# Fries               628.125176  2464.205854
# Sides & Other       200.400802  1000.000000
